# %%
from models.monte_carlo import AmericanMCAnalyzer, EuropeanMCAnalyzer

# %%
contract = {
    "spot": 100.0,
    "strike": 105.0,
    "time_to_maturity": 1.0,
    "risk_free_rate": 0.03,
    "volatility": 0.25,
    "option_type": "call",
}

# %%
european_analyzer = EuropeanMCAnalyzer(num_simulations=5000_000, seed=42)
american_analyzer = AmericanMCAnalyzer(
    num_simulations=100_000,
    num_steps=500,
    seed=42,
    regression_type="quadratic",
)

# %%
result_european = european_analyzer.analyze(contract)
result_american = american_analyzer.analyze(contract)

# %%
print("European:", result_european)
print("American:", result_american)
# Out:
# European: {'price': 9.129240413437604, 'delta': 0.5202539742965753, 'gamma': 0.015901863378330106, 'vega': 39.87522028125427, 'theta': -6.283888645360314, 'rho': 42.896904877118835}
# American: {'price': 9.191461451781255, 'delta': 0.522069415084121, 'gamma': 0.015859884137013225, 'vega': 40.184593072913884, 'theta': -6.325834756667348, 'rho': 43.01618416541215}
